# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd

# %%
data=pd.read_excel('data/ANOM_1 export final_ALBI.xlsx')

# %%
data.head()
# Out:
#   Informations utilisateur  Informations utilisateur .1  \
# 0    identifiantUtilisateur               genreMasculin
# 1                         1                        True
# 2                         2                       False
# 3                         3                        True
# 4                         4                        True
#
#   Informations utilisateur .2 Informations utilisateur .3  \
# 0                 lastConnect                    boursier
# 1              10/03/21 09:41                        True
# 2              24/03/21 16:03                       False
# 3              14/04/21 08:09                       False
# 4              16/03/21 13:24                       False
#
#   Informations utilisateur .4 Informations générales du cursus   \
# 0                  tiersTemps            nom de la ville cursus
# 1                       False                            Amiens
# 2                       False                               NaN
# 3                       False                            Tarbes
# 4                       False                   Aix-en-Provence
#
#   Informations générales du cursus .1 Informations générales du cursus .2  \
# 0                   codePostal cursus       nom de l'établissement cursus
# 1                               80025                              ET0334
# 2                                 NaN                              ET0000
# 3                               65016                              ET0260
# 4                               13625                              ET0001
#
#                   Dossier               Dossier .1  ...  \
# 0  dateInscription dossier  dateSoumission dossier  ...
# 1           23/02/21 21:09          06/03/21 22:06  ...
# 2           01/02/21 16:42          26/02/21 19:44  ...
# 3           26/02/21 22:18          07/03/21 23:33  ...
# 4           06/02/21 10:05          09/03/21 21:01  ...
#
#                            Formation.18  \
# 0  Télécom Paris Parcours CyberSécurité
# 1                                   non
# 2                                   non
# 3                                   non
# 4                                   non
#
#                                      Formation.19  \
# 0  Télécom Paris Parcours Réseaux Télécoms et IoT
# 1                                             non
# 2                                             non
# 3                                             non
# 4                                             non
#
#                                 Formation.20  \
# 0  Télécom Paris Parcours Systèmes Embarqués
# 1                                        non
# 2                                        non
# 3                                        non
# 4                                        non
#
#                                         Formation.21  \
# 0  Mines Nancy : Génie Mécanique parcours Ingénie...
# 1                                         Admissible
# 2                                                non
# 3                                                non
# 4                                       Non convoqué
#
#                     Formation.22                                 Formation.23  \
# 0  Mines ParisTech : Energétique  ENSSAT : Informatique Multimédia et Réseaux
# 1                            non                                          non
# 2                            non                                          non
# 3                            non                                          non
# 4                            non                                          non
#
#                             Formation.24  \
# 0  SIGMA : Mécanique et Génie Industriel
# 1                                    non
# 2                           Non convoqué
# 3                                    non
# 4                             Admissible
#
#                                         Formation.25 Formation.26 Formation.27
# 0  Télécom Physique Strasbourg  : Electronique et...       ET0215       ET0215
# 1                                                non          non          non
# 2                                                non          non          non
# 3                                                non          non          non
# 4                                                non          non          non
#
# [5 rows x 333 columns]
